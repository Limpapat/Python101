# %% [markdown]
# # Python 101 : Pandas : Data Preprocessing [Part 2]
# by Limpapat Bussaban
#
# 04/09/2021
#
# [pandas] Python Data Analysis Library https://pandas.pydata.org
#
# [Datacamp] Cheat sheets http://datacamp-community-prod.s3.amazonaws.com/f04456d7-8e61-482f-9cc9-da6f7f25fc9b
#
# [pandas] Cheat sheets https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ```
# pd.DataFrame(data=None, index: Optional[Axes]=None, columns: Optional[Axes]=None, dtype: Optional[Dtype]=None)
# ```

# %%
header = ("date", "item", "price")
content = [
    ("2020-02-07", "Milk", 26.5),
    ("2020-02-08", "Water", 7),
    ("2020-02-08", "Mask", 20),
    ("2020-02-08", "Lays", 10),
    ("2020-02-08", "Rice", 6)
]

# %% [markdown]
# ### Indexing, Slicing & Filtering

# %% [markdown]
# ```
# df[column]
# df[column][row]
# df[start:stop:step] # -> row only
# df[column_list]
# df[condition]
# df.loc[label_index]
# df.iloc[position_index]
# ```

# %% [markdown]
# ### Useful functions

# %% [markdown]
# **Math operators :**
# ```
#  + - * ** / // %
# ```

# %% [markdown]
# **Functions :**
# see --> https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# ```
# df.groupby()
# ```

# %% [markdown]
# ## Read from file

# %% [markdown]
# ```
# pd.read_csv()
# pd.read_excel()
# pd.read_html()
# pd.read_json()
# pd.read_hdf()
# pd.read_sql()
# ```

# %%
# !mkdir mydata
# !gdown --id 1sEpg7pXYDYKwoDSVtjOdTxBeRhNbv9yk --output /content/mydata/houseprices.csv
# !gdown --id 1Vksn-jDcCATC4-59xmC0Qio0Cq10MBbF --output /content/mydata/iris.xlsx
